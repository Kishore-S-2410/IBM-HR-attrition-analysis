# %%
import pandas as pd
import numpy as np                          #importing required libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("HR-Employee-Attrition.csv")   #Reading dataset

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
sns.displot(x = "Age", hue = "Attrition",element = "poly", data = df, kde = True)  #Attrition vs Age

# %%
sns.countplot(x = "Gender",hue = "Attrition",data = df)  #Attrition vs gender
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x = "OverTime",hue = "Attrition",data = df)    #Overtime vs Attrition
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %%
sns.countplot(x='BusinessTravel',palette = "Set3", hue='Attrition', data=df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %%
sns.countplot(x='MaritalStatus', hue='Attrition', palette = "Set3", data=df)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %%
dummy_col=[column for column in df.drop('Attrition',axis=1).columns if df[column].nunique()<20]
df=pd.get_dummies(df,columns=dummy_col,drop_first=True,dtype='uint8')

# %%
df
# Out:
#       Age Attrition  DailyRate  DistanceFromHome  EmployeeNumber  HourlyRate  \
# 0      41       Yes       1102                 1               1          94
# 1      49        No        279                 8               2          61
# 2      37       Yes       1373                 2               4          92
# 3      33        No       1392                 3               5          56
# 4      27        No        591                 2               7          40
# ...   ...       ...        ...               ...             ...         ...
# 1465   36        No        884                23            2061          41
# 1466   39        No        613                 6            2062          42
# 1467   27        No        155                 4            2064          87
# 1468   49        No       1023                 2            2065          63
# 1469   34        No        628                 8            2068          82
#
# ...

# %%
df['Attrition'] = df['Attrition'].map({'Yes':1,'No':0})

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  EmployeeNumber  HourlyRate  \
# 0      41          1       1102                 1               1          94
# 1      49          0        279                 8               2          61
# 2      37          1       1373                 2               4          92
# 3      33          0       1392                 3               5          56
# 4      27          0        591                 2               7          40
# ...   ...        ...        ...               ...             ...         ...
# 1465   36          0        884                23            2061          41
# 1466   39          0        613                 6            2062          42
# 1467   27          0        155                 4            2064          87
# 1468   49          0       1023                 2            2065          63
# 1469   34          0        628                 8            2068          82
#
# ...

# %%
df=df.T.drop_duplicates()
df=df.T

# %%
df
# Out:
#       Age  Attrition  DailyRate  DistanceFromHome  EmployeeNumber  HourlyRate  \
# 0      41          1       1102                 1               1          94
# 1      49          0        279                 8               2          61
# 2      37          1       1373                 2               4          92
# 3      33          0       1392                 3               5          56
# 4      27          0        591                 2               7          40
# ...   ...        ...        ...               ...             ...         ...
# 1465   36          0        884                23            2061          41
# 1466   39          0        613                 6            2062          42
# 1467   27          0        155                 4            2064          87
# 1468   49          0       1023                 2            2065          63
# 1469   34          0        628                 8            2068          82
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

x=df.drop('Attrition',axis=1)
y=df.Attrition

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=20,stratify=y)

scaler=StandardScaler()
x_train_std=scaler.fit_transform(x_train)
x_test_std=scaler.fit_transform(x_test)
x_std=scaler.fit_transform(x)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train_std,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
pred_train=model.predict(x_train_std)

# %%
accuracy_score(y_train,pred_train)
# Out:
# 0.9212827988338192

# %%
pred=model.predict(x_test_std)

# %%
accuracy_score(y_test,pred)
# Out:
# 0.8435374149659864

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[340,  30],
#        [ 39,  32]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier

rf_clf = RandomForestClassifier(n_estimators=100, bootstrap=False)

# %%
rf_clf.fit(x_train_std, y_train)
# Out:
# RandomForestClassifier(bootstrap=False)

# %%
pred_rf=rf_clf.predict(x_test_std)

# %%
accuracy_score(y_test,pred_rf)
# Out:
# 0.8639455782312925
